# %% [markdown]
# #This notebook shows how to:
#
# - visualize a satelite view of Australia
# - add data to it
# - visualize a geologic map
# - add main river courses to the geologic map

# %%
#RD: please remove libraries that aren't used in this notebook
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

import cartopy.crs as ccrs
import cartopy.feature as cfeature
import cartopy.io.img_tiles as cimgt
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
from cartopy.feature import NaturalEarthFeature

# %%
#RD: No action needed, this is a placeholder
#load datasets

# %%
#RD: change the lat and lon so that it shows Australia instead
# N_LAT: -10
# S_LAT: -44
# E_LONG: 154
# W_LONG: 113



mapbox_satellite = cimgt.MapboxTiles(map_id='satellite', 
                                     access_token='pk.eyJ1IjoibG91aXNtb3Jlc2kiLCJhIjoiY2pzeG1mZzFqMG5sZDQ0czF5YzY1NmZ4cSJ9.lpsUzmLasydBlS0IOqe5JA')
google_maps_satellite = cimgt.GoogleTiles(style="satellite") 

google_maps_satellite = cimgt.GoogleTiles(style="satellite") 


# # Specify a region of interest
lat0 =  0; lat1 = -12; lon0 =  129; lon1 = 154
map_extent = [lon0, lon1, lat0, lat1]
map_tiles = mapbox_satellite
fig = plt.figure(figsize=(12, 12), facecolor="none")

# Create a GeoAxes in the tile's projection.
ax = plt.axes(projection=map_tiles.crs)
ax.set_extent(map_extent)
ax.add_image(google_maps_satellite, 6)#10

#Add coordinates
gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,linewidth=1,
                  color='gray', alpha=0.5)
gl.xlabels_top = False
gl.ylabels_left = False
gl.xformatter = LONGITUDE_FORMATTER
gl.yformatter = LATITUDE_FORMATTER

#plot data
# ax.plot( Crowhurst.Longitude, Crowhurst.Latitude*-1, '*', color='r', alpha=.5, transform=ccrs.Geodetic(), label='Crowhurst AFT')
# ax.plot( Weiland_Cloos.Longitude, Weiland_Cloos.Latitude*-1, '*', color='b',alpha=.5, transform=ccrs.Geodetic(), label='Weiland Cloos AFT')
# ax.plot( Mahoney.Longitude, Mahoney.Latitude, '*', color='magenta', alpha=.5,  transform=ccrs.Geodetic(), label='Mahoney ')
# ax.plot( Holm.Longitude, Holm.Latitude, 'o', color='gold', alpha=.5,  transform=ccrs.Geodetic(), label='Holm ')

        
ax.add_feature(cfeature.RIVERS)
# ax.add_feature(coast, edgecolor='gray')

#Color code by age range or do a loop and color-code the points using np.linspace(color)...
# ax.add_feature(cfeature.STATES, edgecolor='grey')

ax.add_feature(cfeature.BORDERS, edgecolor='black')
ax.legend(loc='lower left')

# %%
#RD: 
#change the lat and lon so that it shows Australia instead
#load the shapefile gregpldd.shp That file is in a zip folder that can be donwloaded here https://ecat.ga.gov.au/geonetwork/srv/eng/catalog.search#/metadata/32366
#'./georegions/shapefiles/gregpldd.shp'

# Specify a region of interest
lat0 =  0; lat1 = -12; lon0 =  129; lon1 = 154
map_extent = [lon0, lon1, lat0, lat1]
map_tiles = mapbox_satellite
fig = plt.figure(figsize=(12, 12), facecolor="none")

# Create a GeoAxes in the tile's projection.
ax = plt.axes(projection=map_tiles.crs)
ax.set_extent(map_extent)
ax.add_image(google_maps_satellite, 6)#10

# %%
#RD: change the lat and lon so that it zooms in New South Wells instead

mapbox_satellite = cimgt.MapboxTiles(map_id='satellite', 
                                     access_token='pk.eyJ1IjoibG91aXNtb3Jlc2kiLCJhIjoiY2pzeG1mZzFqMG5sZDQ0czF5YzY1NmZ4cSJ9.lpsUzmLasydBlS0IOqe5JA')
google_maps_satellite = cimgt.GoogleTiles(style="satellite") 

google_maps_satellite = cimgt.GoogleTiles(style="satellite") 
# # Specify a region of interest
lat0 =  -3.9; lat1 = -5; lon0 =  136; lon1 = 138
map_extent = [lon0, lon1, lat0, lat1]
map_tiles = mapbox_satellite
fig = plt.figure(figsize=(12, 12), facecolor="none")

# Create a GeoAxes in the tile's projection.
ax = plt.axes(projection=map_tiles.crs)
ax.set_extent(map_extent)
ax.add_image(google_maps_satellite, 10)#10

#Add coordinates
gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,linewidth=2,
                  color='gray', alpha=0.5)
gl.xlabels_top = False
gl.ylabels_left = False
# gl.xlines = False
# gl.xlocator = mticker.FixedLocator([-100, -90, -80, -70])
gl.xformatter = LONGITUDE_FORMATTER
gl.yformatter = LATITUDE_FORMATTER

# ax.plot( Weiland_Cloos.Longitude, Weiland_Cloos.Latitude*-1, '*', color='b', transform=ccrs.Geodetic(), label='Weiland&Cloos ')


# ax.add_feature(coast, edgecolor='gray')


#Color code by age range or do a loop and color-code the points using np.linspace(color)...
# ax.add_feature(cfeature.STATES, edgecolor='grey')
ax.legend()
